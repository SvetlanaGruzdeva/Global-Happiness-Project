# %%
import os
import re
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
import pymysql
import requests
from bs4 import BeautifulSoup
from sklearn.linear_model import LinearRegression
from statsmodels.tsa.ar_model import AR
from scipy import stats

# %%
pd.set_option('display.max_columns', 100)
sqlpassword = os.environ['SQLpassword']
engine = create_engine(f"mysql+pymysql://root:{sqlpassword}@127.0.0.1/world_happiness")

# %% [markdown]
# ## **Step 1.** Reading and cleaning data.

# %% [markdown]
# ### a) Extraction of standartised country codes and names for further unification of data sets.

# %%
url = 'https://www.iban.com/country-codes'
html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")
cdict = {'class':'table'}
table = soup.find_all('table', cdict)[0]
rows = table.find_all('td')
rows = [x.contents[0] for x in rows]
rows[:21]
# Out:
# ['Afghanistan',
#  'AF',
#  'AFG',
#  '004',
#  'Åland Islands',
#  'AX',
#  'ALA',
#  '248',
#  'Albania',
#  'AL',
#  'ALB',
#  '008',
#  'Algeria',
#  'DZ',
#  'DZA',
#  '012',
#  'American Samoa',
#  'AS',
#  'ASM',
#  '016',
#  'Andorra']

# %%
# There are 4 columns in a table so we split all content of a table in lists of 4 elements each.
n_countries = int(len(rows)/4)
countries = np.array_split(rows, n_countries)

# Convert list of rows values into dataframe.
df_countries = pd.DataFrame(countries,columns=['Country', 'Alpha-2 code', 'Alpha-3 code', 'Numeric'])

# Rename some countries to make them more readable on future graphs. Code below came up as a result of review each data set
# below.

pat1 = r" \(the\)"
pat2 = r" \(the Republic of\)"
combined_pat = r'|'.join((pat1, pat2))
df_countries['Country'] = df_countries['Country'].map(lambda x: re.sub(combined_pat, '', x))
old_names = ['United Kingdom of Great Britain and Northern Ireland', 'United States of America', 'Korea',
             'Bolivia (Plurinational State of)', 'Iran (Islamic Republic of)', "Lao People's Democratic Republic",
             'Republic of North Macedonia', 'Palestine, State of', 'Eswatini', 'Syrian Arab Republic',
             'Tanzania, United Republic of', 'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'Åland Islands']

new_names = ['United Kingdom', 'United States', 'South Korea', 'Bolivia', 'Iran', 'Laos', 'Macedonia', 'Palestine', 
            'Swaziland (Eswatini)', 'Syria', 'Tanzania', 'Venezuela', 'Vietnam', 'Aland Islands']

df_countries['Country'].replace(old_names, new_names, inplace=True)
czech = {'Country':'Czech Republic', 'Alpha-2 code':'CZ', 'Alpha-3 code':'CZE', 'Numeric':'420'}
df_countries = df_countries.append(czech, ignore_index=True)

# Form dictionary out of 2 suitable columns.
countries_dict = dict(zip(df_countries['Alpha-3 code'], df_countries['Country']))
countries_dict
# Out:
# {'AFG': 'Afghanistan',
#  'ALA': 'Aland Islands',
#  'ALB': 'Albania',
#  'DZA': 'Algeria',
#  'ASM': 'American Samoa',
#  'AND': 'Andorra',
#  'AGO': 'Angola',
#  'AIA': 'Anguilla',
#  'ATA': 'Antarctica',
#  'ATG': 'Antigua and Barbuda',
#  'ARG': 'Argentina',
#  'ARM': 'Armenia',
#  'ABW': 'Aruba',
#  'AUS': 'Australia',
#  'AUT': 'Austria',
#  'AZE': 'Azerbaijan',
#  'BHS': 'Bahamas',
#  'BHR': 'Bahrain',
#  'BGD': 'Bangladesh',
#  'BRB': 'Barbados',
#  'BLR': 'Belarus',
#  'BEL': 'Belgium',
#  'BLZ': 'Belize',
#  'BEN': 'Benin',
#  'BMU': 'Bermuda',
#  'BTN': 'Bhutan',
#  'BOL': 'Bolivia',
#  'BES': 'Bonaire, Sint Eustatius and Saba',
#  'BIH': 'Bosnia and Herzegovina',
#  'BWA': 'Botswana',
#  'BVT': 'Bouvet Island',
#  'BRA': 'Brazil',
#  'IOT': 'British Indian Ocean Territory',
#  'BRN': 'Brunei Darussalam',
#  'BGR': 'Bulgaria',
#  'BFA': 'Burkina Faso',
#  'BDI': 'Burundi',
#  'CPV': 'Cabo Verde',
#  'KHM': 'Cambodia',
#  'CMR': 'Cameroon',
#  'CAN': 'Canada',
#  'CYM': 'Cayman Islands',
#  'CAF': 'Central African Republic',
#  'TCD': 'Chad',
#  'CHL': 'Chile',
#  'CHN': 'China',
#  'CXR': 'Christmas Island',
#  'CCK': 'Cocos (Keeling) Islands',
#  'COL': 'Colombia',
#  'COM': 'Comoros',
#  'COD': 'Congo (the Democratic Republic of the)',
#  'COG': 'Congo',
#  'COK': 'Cook Islands',
#  'CRI': 'Costa Rica',
#  'CIV': "Côte d'Ivoire",
#  'HRV': 'Croatia',
#  'CUB': 'Cuba',
#  'CUW': 'Curaçao',
#  'CYP': 'Cyprus',
#  'CZE': 'Czech Republic',
#  'DNK': 'Denmark',
#  'DJI': 'Djibouti',
#  'DMA': 'Dominica',
#  'DOM': 'Dominican Republic',
#  'ECU': 'Ecuador',
#  'EGY': 'Egypt',
#  'SLV': 'El Salvador',
#  'GNQ': 'Equatorial Guinea',
#  'ERI': 'Eritrea',
#  'EST': 'Estonia',
#  'SWZ': 'Swaziland (Eswatini)',
#  'ETH': 'Ethiopia',
#  'FLK': 'Falkland Islands [Malvinas]',
#  'FRO': 'Faroe Islands',
#  'FJI': 'Fiji',
#  'FIN': 'Finland',
#  'FRA': 'France',
#  'GUF': 'French Guiana',
#  'PYF': 'French Polynesia',
#  'ATF': 'French Southern Territories',
#  'GAB': 'Gabon',
#  'GMB': 'Gambia',
#  'GEO': 'Georgia',
#  'DEU': 'Germany',
#  'GHA': 'Ghana',
#  'GIB': 'Gibraltar',
#  'GRC': 'Greece',
#  'GRL': 'Greenland',
#  'GRD': 'Grenada',
#  'GLP': 'Guadeloupe',
#  'GUM': 'Guam',
#  'GTM': 'Guatemala',
#  'GGY': 'Guernsey',
#  'GIN': 'Guinea',
#  'GNB': 'Guinea-Bissau',
#  'GUY': 'Guyana',
#  'HTI': 'Haiti',
#  'HMD': 'Heard Island and McDonald Islands',
#  'VAT': 'Holy See',
#  'HND': 'Honduras',
#  'HKG': 'Hong Kong',
#  'HUN': 'Hungary',
#  'ISL': 'Iceland',
#  'IND': 'India',
#  'IDN': 'Indonesia',
#  'IRN': 'Iran',
#  'IRQ': 'Iraq',
#  'IRL': 'Ireland',
#  'IMN': 'Isle of Man',
#  'ISR': 'Israel',
#  'ITA': 'Italy',
#  'JAM': 'Jamaica',
#  'JPN': 'Japan',
#  'JEY': 'Jersey',
#  'JOR': 'Jordan',
#  'KAZ': 'Kazakhstan',
#  'KEN': 'Kenya',
#  'KIR': 'Kiribati',
#  'PRK': "Korea (the Democratic People's Republic of)",
#  'KOR': 'South Korea',
#  'KWT': 'Kuwait',
#  'KGZ': 'Kyrgyzstan',
#  'LAO': 'Laos',
#  'LVA': 'Latvia',
#  'LBN': 'Lebanon',
#  'LSO': 'Lesotho',
#  'LBR': 'Liberia',
#  'LBY': 'Libya',
#  'LIE': 'Liechtenstein',
#  'LTU': 'Lithuania',
#  'LUX': 'Luxembourg',
#  'MAC': 'Macao',
#  'MKD': 'Macedonia',
#  'MDG': 'Madagascar',
#  'MWI': 'Malawi',
#  'MYS': 'Malaysia',
#  'MDV': 'Maldives',
#  'MLI': 'Mali',
#  'MLT': 'Malta',
#  'MHL': 'Marshall Islands',
#  'MTQ': 'Martinique',
#  'MRT': 'Mauritania',
#  'MUS': 'Mauritius',
#  'MYT': 'Mayotte',
#  'MEX': 'Mexico',
#  'FSM': 'Micronesia (Federated States of)',
#  'MDA': 'Moldova',
#  'MCO': 'Monaco',
#  'MNG': 'Mongolia',
#  'MNE': 'Montenegro',
#  'MSR': 'Montserrat',
#  'MAR': 'Morocco',
#  'MOZ': 'Mozambique',
#  'MMR': 'Myanmar',
#  'NAM': 'Namibia',
#  'NRU': 'Nauru',
#  'NPL': 'Nepal',
#  'NLD': 'Netherlands',
#  'NCL': 'New Caledonia',
#  'NZL': 'New Zealand',
#  'NIC': 'Nicaragua',
#  'NER': 'Niger',
#  'NGA': 'Nigeria',
#  'NIU': 'Niue',
#  'NFK': 'Norfolk Island',
#  'MNP': 'Northern Mariana Islands',
#  'NOR': 'Norway',
#  'OMN': 'Oman',
#  'PAK': 'Pakistan',
#  'PLW': 'Palau',
#  'PSE': 'Palestine',
#  'PAN': 'Panama',
#  'PNG': 'Papua New Guinea',
#  'PRY': 'Paraguay',
#  'PER': 'Peru',
#  'PHL': 'Philippines',
#  'PCN': 'Pitcairn',
#  'POL': 'Poland',
#  'PRT': 'Portugal',
#  'PRI': 'Puerto Rico',
#  'QAT': 'Qatar',
#  'REU': 'Réunion',
#  'ROU': 'Romania',
#  'RUS': 'Russian Federation',
#  'RWA': 'Rwanda',
#  'BLM': 'Saint Barthélemy',
#  'SHN': 'Saint Helena, Ascension and Tristan da Cunha',
#  'KNA': 'Saint Kitts and Nevis',
#  'LCA': 'Saint Lucia',
#  'MAF': 'Saint Martin (French part)',
#  'SPM': 'Saint Pierre and Miquelon',
#  'VCT': 'Saint Vincent and the Grenadines',
#  'WSM': 'Samoa',
#  'SMR': 'San Marino',
#  'STP': 'Sao Tome and Principe',
#  'SAU': 'Saudi Arabia',
#  'SEN': 'Senegal',
#  'SRB': 'Serbia',
#  'SYC': 'Seychelles',
#  'SLE': 'Sierra Leone',
#  'SGP': 'Singapore',
#  'SXM': 'Sint Maarten (Dutch part)',
#  'SVK': 'Slovakia',
#  'SVN': 'Slovenia',
#  'SLB': 'Solomon Islands',
#  'SOM': 'Somalia',
#  'ZAF': 'South Africa',
#  'SGS': 'South Georgia and the South Sandwich Islands',
#  'SSD': 'South Sudan',
#  'ESP': 'Spain',
#  'LKA': 'Sri Lanka',
#  'SDN': 'Sudan',
#  'SUR': 'Suriname',
#  'SJM': 'Svalbard and Jan Mayen',
#  'SWE': 'Sweden',
#  'CHE': 'Switzerland',
#  'SYR': 'Syria',
#  'TWN': 'Taiwan (Province of China)',
#  'TJK': 'Tajikistan',
#  'TZA': 'Tanzania',
#  'THA': 'Thailand',
#  'TLS': 'Timor-Leste',
#  'TGO': 'Togo',
#  'TKL': 'Tokelau',
#  'TON': 'Tonga',
#  'TTO': 'Trinidad and Tobago',
#  'TUN': 'Tunisia',
#  'TUR': 'Turkey',
#  'TKM': 'Turkmenistan',
#  'TCA': 'Turks and Caicos Islands',
#  'TUV': 'Tuvalu',
#  'UGA': 'Uganda',
#  'UKR': 'Ukraine',
#  'ARE': 'United Arab Emirates',
#  'GBR': 'United Kingdom',
#  'UMI': 'United States Minor Outlying Islands',
#  'USA': 'United States',
#  'URY': 'Uruguay',
#  'UZB': 'Uzbekistan',
#  'VUT': 'Vanuatu',
#  'VEN': 'Venezuela',
#  'VNM': 'Vietnam',
#  'VGB': 'Virgin Islands (British)',
#  'VIR': 'Virgin Islands (U.S.)',
#  'WLF': 'Wallis and Futuna',
#  'ESH': 'Western Sahara',
#  'YEM': 'Yemen',
#  'ZMB': 'Zambia',
#  'ZWE': 'Zimbabwe'}

# %% [markdown]
# ***Analysis of each unmached value from data set 'happiness rating':***
#
# 'Congo (Brazzaville)' - rename in *happiness* \
# 'Congo (Kinshasa)' - rename in *happiness* \
# 'Hong Kong S.A.R. China' - rename in *happiness* \
# 'Iran' - rename in *countries* \
# 'Ivory Coast' - keep\
# 'Kosovo' - keep\
# 'Laos' - rename in *countries* \
# 'Macedonia' - rename in *countries* \
# 'North Cyprus'  - rename in *happiness*\
# 'North Macedonia' - rename in *happiness*\
# 'Northern Cyprus' - keep \
# 'Palestinian Territories' - rename in *happiness*\
# 'Russia' - rename in *happiness* \
# 'Somaliland Region' - keep\
# 'Somaliland region' - rename in *happiness*\
# 'South Korea' - rename in *countries* \
# 'Swaziland' - rename in *countries* & *happiness*\
# 'Syria' - rename in *countries*\
# 'Taiwan' - rename in *happiness*\
# 'Taiwan Province of China' - rename in *happiness*\
# 'Tanzania' - rename in *countries*\
# 'Trinidad & Tobago' - rename in *happiness*\
# 'Venezuela' - rename in *countries*\
# 'Vietnam' - rename in *countries*

# %%
# Defining two functions which will be used to check and amend country names spelling.

def country_name(row):
    for key, value in countries_dict.items():
        if row.Country == key:
            return value

def country_code(row):
    for key, value in countries_dict.items():
        if row.Country == value:
            return key

# %% [markdown]
# ### b) Combining data sets for various periods in one table based on data topic.

# %% [markdown]
# ### *Suicide data.*

# %%
df_suicide_new = pd.read_sql_query('''SELECT * FROM world_happiness.suicide_2015_2018''', engine)
df_suicide_new = df_suicide_new.rename(columns={'LOCATION': 'Country'})
df_suicide_new.head()
# Out:
#   Country INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value
# 0     AUS   SUICIDE     TOT  100000PER         A  2015   13.1
# 1     AUS   SUICIDE     TOT  100000PER         A  2016   12.1
# 2     AUS   SUICIDE     TOT  100000PER         A  2017   12.8
# 3     AUT   SUICIDE     TOT  100000PER         A  2015   12.9
# 4     AUT   SUICIDE     TOT  100000PER         A  2016   12.2

# %%
df_suicide_new['Country'] = df_suicide_new.apply(lambda row: country_name(row), axis=1)
df_suicide_new.head()
# Out:
#      Country INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value
# 0  Australia   SUICIDE     TOT  100000PER         A  2015   13.1
# 1  Australia   SUICIDE     TOT  100000PER         A  2016   12.1
# 2  Australia   SUICIDE     TOT  100000PER         A  2017   12.8
# 3    Austria   SUICIDE     TOT  100000PER         A  2015   12.9
# 4    Austria   SUICIDE     TOT  100000PER         A  2016   12.2

# %%
df_suicide_worldbank = pd.read_csv('.\\data\\suicide.csv')  # It was last minute change so row data is not saved in SQL satabase
df_suicide_worldbank = df_suicide_worldbank[['Country Name', 'Country Code', 'Year', 'Stat']]
df_suicide_worldbank.columns = ['Country', 'Country_Code', 'Year', 'Suicide_rate_per_100K']
df_suicide_worldbank.head()
# Out:
#        Country Country_Code  Year  Suicide_rate_per_100K
# 0        Aruba          ABW  2015                    NaN
# 1  Afghanistan          AFG  2015                    4.8
# 2       Angola          AGO  2015                    5.0
# 3      Albania          ALB  2015                    6.0
# 4      Andorra          AND  2015                    NaN

# %%
df_suicide_worldbank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                528 non-null    object
#  1   Country_Code           528 non-null    object
#  2   Year                   528 non-null    int64
#  3   Suicide_rate_per_100K  458 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 16.6+ KB

# %%
df_suicide_worldbank = df_suicide_worldbank.dropna()
df_suicide_worldbank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 458 entries, 1 to 527
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                458 non-null    object
#  1   Country_Code           458 non-null    object
#  2   Year                   458 non-null    int64
#  3   Suicide_rate_per_100K  458 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 17.9+ KB

# %%
# Check spelling of countries. It should be unified accross all data sets as this field will be used for merging eventually.

df_suicide_new['Country_Code'] = df_suicide_new.apply(lambda row: country_code(row), axis=1)
df_suicide_new.head()
# Out:
#      Country INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value Country_Code
# 0  Australia   SUICIDE     TOT  100000PER         A  2015   13.1          AUS
# 1  Australia   SUICIDE     TOT  100000PER         A  2016   12.1          AUS
# 2  Australia   SUICIDE     TOT  100000PER         A  2017   12.8          AUS
# 3    Austria   SUICIDE     TOT  100000PER         A  2015   12.9          AUT
# 4    Austria   SUICIDE     TOT  100000PER         A  2016   12.2          AUT

# %%
# List of countries which spelling is different from international standards.

df_suicide_new.loc[df_suicide_new['Country_Code'].isnull()]['Country'].unique()
# Out:
# array([], dtype=object)

# %%
df1 = df_suicide_new[['Country', 'TIME', 'Value', 'Country_Code']]
df1.columns = ['Country', 'Year', 'Suicide_rate_per_100K', 'Country_Code']
df1 = df1.loc[df1['Year'].isin([2017, 2018])]

df2 = df_suicide_worldbank[['Country', 'Year', 'Suicide_rate_per_100K', 'Country_Code']]
df2.columns=['Country', 'Year', 'Suicide_rate_per_100K', 'Country_Code']
frames = [df1, df2]
df_suicide = pd.concat(frames)

df_suicide.head()
# Out:
#            Country  Year  Suicide_rate_per_100K Country_Code
# 2        Australia  2017                   12.8          AUS
# 5          Austria  2017                   12.4          AUT
# 10          Canada  2017                   11.0          CAN
# 13  Czech Republic  2017                   12.4          CZE
# 16         Finland  2017                   14.6          FIN

# %%
df_suicide.to_sql('suicide_consol', engine, 'world_happiness', if_exists='replace')

# %% [markdown]
# ### *Global happiness data.*

# %%
df_happiness_2015 = pd.read_sql_query('''SELECT * FROM world_happiness.world_happiness_2015''', engine)
df_happiness_2015['Year'] = '2015'
df_happiness_2015.head()
# Out:
#        Country          Region  Happiness_Rank  Happiness_Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard_Error  Economy_GDP_per_Capita   Family  Health_Life_Expectancy  \
# 0         0.03411                 1.39651  1.34951                 0.94143
# 1         0.04884                 1.30232  1.40223                 0.94784
# 2         0.03328                 1.32548  1.36058                 0.87464
# 3         0.03880                 1.45900  1.33095                 0.88521
# 4         0.03553                 1.32629  1.32261                 0.90563
#
#    Freedom  Trust_Government_Corruption  Generosity  Dystopia_Residual  Year
# 0  0.66557                      0.41978     0.29678            2.51738  2015
# 1  0.62877                      0.14145     0.43630            2.70201  2015
# 2  0.64938                      0.48357     0.34139            2.49204  2015
# 3  0.66973                      0.36503     0.34699            2.46531  2015
# 4  0.63297                      0.32957     0.45811            2.45176  2015

# %%
df_happiness_2016 = pd.read_sql_query('''SELECT * FROM world_happiness.world_happiness_2016''', engine)
df_happiness_2016['Year'] = '2016'
df_happiness_2016.head()
# Out:
#        Country          Region  Happiness_Rank  Happiness_Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower_Confidence_Interval  Upper_Confidence_Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy_GDP_per_Capita   Family  Health_Life_Expectancy  Freedom  \
# 0                 1.44178  1.16374                 0.79504  0.57941
# 1                 1.52733  1.14524                 0.86303  0.58557
# 2                 1.42666  1.18326                 0.86733  0.56624
# 3                 1.57744  1.12690                 0.79579  0.59609
# 4                 1.40598  1.13464                 0.81091  0.57104
#
#    Trust_Government_Corruption  Generosity  Dystopia_Residual  Year
# 0                      0.44453     0.36171            2.73939  2016
# 1                      0.41203     0.28083            2.69463  2016
# 2                      0.14975     0.47678            2.83137  2016
# 3                      0.35776     0.37895            2.66465  2016
# 4                      0.41004     0.25492            2.82596  2016

# %%
df_happiness_2017 = pd.read_sql_query('''SELECT * FROM world_happiness.world_happiness_2017''', engine)
df_happiness_2017['Year'] = '2017'
df_happiness_2017.head()
# Out:
#        Country  Happiness_Rank  Happiness_Score  Whisker_high  Whisker_low  \
# 0       Norway               1            7.537       7.59444      7.47956
# 1      Denmark               2            7.522       7.58173      7.46227
# 2      Iceland               3            7.504       7.62203      7.38597
# 3  Switzerland               4            7.494       7.56177      7.42623
# 4      Finland               5            7.469       7.52754      7.41046
#
#    Economy_GDP_per_Capita   Family  Health_Life_Expectancy   Freedom  \
# 0                 1.61646  1.53352                0.796667  0.635423
# 1                 1.48238  1.55112                0.792566  0.626007
# 2                 1.48063  1.61057                0.833552  0.627163
# 3                 1.56498  1.51691                0.858131  0.620071
# 4                 1.44357  1.54025                0.809158  0.617951
#
#    Generosity  Trust_Government_Corruption  Dystopia_Residual  Year
# 0    0.362012                     0.315964            2.27703  2017
# 1    0.355280                     0.400770            2.31371  2017
# 2    0.475540                     0.153527            2.32272  2017
# 3    0.290549                     0.367007            2.27672  2017
# 4    0.245483                     0.382612            2.43018  2017

# %%
df_happiness_2018 = pd.read_sql_query('''SELECT * FROM world_happiness.world_happiness_2018''', engine)
df_happiness_2018['Year'] = '2018'
df_happiness_2018.head()
# Out:
#    Happiness_Rank Country_or_region  Happiness_Score  Economy_GDP_per_Capita  \
# 0               1           Finland            7.632                   1.305
# 1               2            Norway            7.594                   1.456
# 2               3           Denmark            7.555                   1.351
# 3               4           Iceland            7.495                   1.343
# 4               5       Switzerland            7.487                   1.420
#
#    Social_support  Health_Life_Expectancy  Freedom  Generosity  \
# 0           1.592                   0.874    0.681       0.202
# 1           1.582                   0.861    0.686       0.286
# 2           1.590                   0.868    0.683       0.284
# 3           1.644                   0.914    0.677       0.353
# 4           1.549                   0.927    0.660       0.256
#
#    Trust_Government_Corruption  Year
# 0                        0.393  2018
# 1                        0.340  2018
# 2                        0.408  2018
# 3                        0.138  2018
# 4                        0.357  2018

# %%
df_happiness_2019 = pd.read_sql_query('''SELECT * FROM world_happiness.world_happiness_2019''', engine)
df_happiness_2019['Year'] = '2019'
df_happiness_2019.head()
# Out:
#    Happiness_Rank Country_or_region  Happiness_Score  Economy_GDP_per_Capita  \
# 0               1           Finland            7.769                   1.340
# 1               2           Denmark            7.600                   1.383
# 2               3            Norway            7.554                   1.488
# 3               4           Iceland            7.494                   1.380
# 4               5       Netherlands            7.488                   1.396
#
#    Social_support  Health_Life_Expectancy  Freedom  Generosity  \
# 0           1.587                   0.986    0.596       0.153
# 1           1.573                   0.996    0.592       0.252
# 2           1.582                   1.028    0.603       0.271
# 3           1.624                   1.026    0.591       0.354
# 4           1.522                   0.999    0.557       0.322
#
#    Trust_Government_Corruption  Year
# 0                        0.393  2019
# 1                        0.410  2019
# 2                        0.341  2019
# 3                        0.118  2019
# 4                        0.298  2019

# %%
# Based on review of all five data sets above some of the columns should be dropped to be able to combine all tables in one.

df_happiness_2015.drop(columns=['Region', 'Standard_Error', 'Dystopia_Residual'], inplace=True)
df_happiness_2015 = df_happiness_2015.rename(columns={'Family': 'Social_support'})
df_happiness_2015.head()
# Out:
#        Country  Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# 0  Switzerland               1            7.587                 1.39651
# 1      Iceland               2            7.561                 1.30232
# 2      Denmark               3            7.527                 1.32548
# 3       Norway               4            7.522                 1.45900
# 4       Canada               5            7.427                 1.32629
#
#    Social_support  Health_Life_Expectancy  Freedom  \
# 0         1.34951                 0.94143  0.66557
# 1         1.40223                 0.94784  0.62877
# 2         1.36058                 0.87464  0.64938
# 3         1.33095                 0.88521  0.66973
# 4         1.32261                 0.90563  0.63297
#
#    Trust_Government_Corruption  Generosity  Year
# 0                      0.41978     0.29678  2015
# 1                      0.14145     0.43630  2015
# 2                      0.48357     0.34139  2015
# 3                      0.36503     0.34699  2015
# 4                      0.32957     0.45811  2015

# %%
df_happiness_2016.drop(columns=['Region', 'Lower_Confidence_Interval', 'Upper_Confidence_Interval', 'Dystopia_Residual'],
                       inplace=True)
df_happiness_2016 = df_happiness_2016.rename(columns={'Family': 'Social_support'})
df_happiness_2016.head()
# Out:
#        Country  Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# 0      Denmark               1            7.526                 1.44178
# 1  Switzerland               2            7.509                 1.52733
# 2      Iceland               3            7.501                 1.42666
# 3       Norway               4            7.498                 1.57744
# 4      Finland               5            7.413                 1.40598
#
#    Social_support  Health_Life_Expectancy  Freedom  \
# 0         1.16374                 0.79504  0.57941
# 1         1.14524                 0.86303  0.58557
# 2         1.18326                 0.86733  0.56624
# 3         1.12690                 0.79579  0.59609
# 4         1.13464                 0.81091  0.57104
#
#    Trust_Government_Corruption  Generosity  Year
# 0                      0.44453     0.36171  2016
# 1                      0.41203     0.28083  2016
# 2                      0.14975     0.47678  2016
# 3                      0.35776     0.37895  2016
# 4                      0.41004     0.25492  2016

# %%
col_list = df_happiness_2015.columns.to_list()

# %%
df_happiness_2017.drop(columns=['Whisker_high', 'Whisker_low', 'Dystopia_Residual'], inplace=True)
df_happiness_2017 = df_happiness_2017.rename(columns={'Family': 'Social_support'})
df_happiness_2017 = df_happiness_2017[col_list]
df_happiness_2017.head()
# Out:
#        Country  Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# 0       Norway               1            7.537                 1.61646
# 1      Denmark               2            7.522                 1.48238
# 2      Iceland               3            7.504                 1.48063
# 3  Switzerland               4            7.494                 1.56498
# 4      Finland               5            7.469                 1.44357
#
#    Social_support  Health_Life_Expectancy   Freedom  \
# 0         1.53352                0.796667  0.635423
# 1         1.55112                0.792566  0.626007
# 2         1.61057                0.833552  0.627163
# 3         1.51691                0.858131  0.620071
# 4         1.54025                0.809158  0.617951
#
#    Trust_Government_Corruption  Generosity  Year
# 0                     0.315964    0.362012  2017
# 1                     0.400770    0.355280  2017
# 2                     0.153527    0.475540  2017
# 3                     0.367007    0.290549  2017
# 4                     0.382612    0.245483  2017

# %%
df_happiness_2018 = df_happiness_2018.rename(columns={'Country_or_region': 'Country'})
df_happiness_2018 = df_happiness_2018[col_list]
df_happiness_2018.head()
# Out:
#        Country  Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# 0      Finland               1            7.632                   1.305
# 1       Norway               2            7.594                   1.456
# 2      Denmark               3            7.555                   1.351
# 3      Iceland               4            7.495                   1.343
# 4  Switzerland               5            7.487                   1.420
#
#    Social_support  Health_Life_Expectancy  Freedom  \
# 0           1.592                   0.874    0.681
# 1           1.582                   0.861    0.686
# 2           1.590                   0.868    0.683
# 3           1.644                   0.914    0.677
# 4           1.549                   0.927    0.660
#
#    Trust_Government_Corruption  Generosity  Year
# 0                        0.393       0.202  2018
# 1                        0.340       0.286  2018
# 2                        0.408       0.284  2018
# 3                        0.138       0.353  2018
# 4                        0.357       0.256  2018

# %%
df_happiness_2019 = df_happiness_2019.rename(columns={'Country_or_region': 'Country'})
df_happiness_2019 = df_happiness_2019[col_list]
df_happiness_2019.head()
# Out:
#        Country  Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# 0      Finland               1            7.769                   1.340
# 1      Denmark               2            7.600                   1.383
# 2       Norway               3            7.554                   1.488
# 3      Iceland               4            7.494                   1.380
# 4  Netherlands               5            7.488                   1.396
#
#    Social_support  Health_Life_Expectancy  Freedom  \
# 0           1.587                   0.986    0.596
# 1           1.573                   0.996    0.592
# 2           1.582                   1.028    0.603
# 3           1.624                   1.026    0.591
# 4           1.522                   0.999    0.557
#
#    Trust_Government_Corruption  Generosity  Year
# 0                        0.393       0.153  2019
# 1                        0.410       0.252  2019
# 2                        0.341       0.271  2019
# 3                        0.118       0.354  2019
# 4                        0.298       0.322  2019

# %%
frames = [df_happiness_2015, df_happiness_2016, df_happiness_2017, df_happiness_2018, df_happiness_2019]

df_happiness = pd.concat(frames)
df_happiness.head()
# Out:
#        Country  Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# 0  Switzerland               1            7.587                 1.39651
# 1      Iceland               2            7.561                 1.30232
# 2      Denmark               3            7.527                 1.32548
# 3       Norway               4            7.522                 1.45900
# 4       Canada               5            7.427                 1.32629
#
#    Social_support  Health_Life_Expectancy  Freedom  \
# 0         1.34951                 0.94143  0.66557
# 1         1.40223                 0.94784  0.62877
# 2         1.36058                 0.87464  0.64938
# 3         1.33095                 0.88521  0.66973
# 4         1.32261                 0.90563  0.63297
#
#    Trust_Government_Corruption  Generosity  Year
# 0                      0.41978     0.29678  2015
# 1                      0.14145     0.43630  2015
# 2                      0.48357     0.34139  2015
# 3                      0.36503     0.34699  2015
# 4                      0.32957     0.45811  2015

# %%
# Check spelling of countries. It should be unified accross all data sets as this field will be used for merging eventually.

df_happiness['Country_Code'] = df_happiness.apply(lambda row: country_code(row), axis=1)
df_happiness.head()
df_happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 782 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      782 non-null    object
#  1   Happiness_Rank               782 non-null    int64
#  2   Happiness_Score              782 non-null    float64
#  3   Economy_GDP_per_Capita       782 non-null    float64
#  4   Social_support               782 non-null    float64
#  5   Health_Life_Expectancy       782 non-null    float64
#  6   Freedom                      782 non-null    float64
#  7   Trust_Government_Corruption  782 non-null    float64
#  8   Generosity                   782 non-null    float64
#  9   Year                         782 non-null    object
#  10  Country_Code                 734 non-null    object
# dtypes: float64(7), int64(1), object(3)
# memory usage: 73.3+ KB

# %%
# List of countries which spelling is different from international standards.

df_happiness.loc[df_happiness['Country_Code'].isnull()]['Country'].unique()
# Out:
# array(['Taiwan', 'Russia', 'North Cyprus', 'Kosovo', 'Somaliland region',
#        'Swaziland', 'Palestinian Territories', 'Congo (Kinshasa)',
#        'Congo (Brazzaville)', 'Ivory Coast', 'Somaliland Region',
#        'Taiwan Province of China', 'Hong Kong S.A.R., China',
#        'Trinidad & Tobago', 'Northern Cyprus', 'North Macedonia'],
#       dtype=object)

# %%
old_names = ['Hong Kong S.A.R., China', 'North Cyprus', 'Palestinian Territories', 'Russia', 'Congo (Kinshasa)',
             'Congo (Brazzaville)', 'Somaliland region', 'Swaziland', 'Taiwan', 'Taiwan Province of China',
             'Trinidad & Tobago']

new_names = ['Hong Kong', 'Northern Cyprus', 'Palestine', 'Russian Federation', 'Congo (the Democratic Republic of the)',
            'Congo', 'Somaliland Region', 'Swaziland (Eswatini)', 'Taiwan (Province of China)', 'Taiwan (Province of China)',
            'Trinidad and Tobago']

df_happiness['Country'].replace(old_names, new_names, inplace=True)

# %%
# Second check to see that everything is unified now.

df_happiness['Country_Code'] = df_happiness.apply(lambda row: country_code(row), axis=1)
df_happiness.loc[df_happiness['Country_Code'].isnull()]['Country'].unique()

# These are areas of territorial disputes and will stay blank for analytical purposes.
# Out:
# array(['Northern Cyprus', 'Kosovo', 'Somaliland Region', 'Ivory Coast',
#        'North Macedonia'], dtype=object)

# %%
df_happiness['Year'] = df_happiness['Year'].astype('int')
df_happiness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 782 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      782 non-null    object
#  1   Happiness_Rank               782 non-null    int64
#  2   Happiness_Score              782 non-null    float64
#  3   Economy_GDP_per_Capita       782 non-null    float64
#  4   Social_support               782 non-null    float64
#  5   Health_Life_Expectancy       782 non-null    float64
#  6   Freedom                      782 non-null    float64
#  7   Trust_Government_Corruption  782 non-null    float64
#  8   Generosity                   782 non-null    float64
#  9   Year                         782 non-null    int32
#  10  Country_Code                 764 non-null    object
# dtypes: float64(7), int32(1), int64(1), object(2)
# memory usage: 70.3+ KB

# %%
df_happiness.to_sql('world_happiness_consol', engine, 'world_happiness', if_exists='replace')

# %% [markdown]
# ### *Climate data.*

# %%
df_climate_raw = pd.read_sql_query('''SELECT * FROM world_happiness.temperature_1900_2013''', engine)
df_climate_raw.drop(columns=['index'], inplace=True)
df_climate_raw.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0  01/01/1900              -3.026                          0.538
# 1  01/02/1900              -8.063                          0.657
# 2  01/03/1900              -3.196                          0.467
# 3  01/04/1900               0.781                          0.224
# 4  01/05/1900               4.960                          0.503
#
#          Country
# 0  Aland Islands
# 1  Aland Islands
# 2  Aland Islands
# 3  Aland Islands
# 4  Aland Islands

# %%
df_climate_raw['dt'] = pd.to_datetime(df_climate_raw['dt'])
df_climate_raw.head()
# Out:
#           dt  AverageTemperature  AverageTemperatureUncertainty        Country
# 0 1900-01-01              -3.026                          0.538  Aland Islands
# 1 1900-01-02              -8.063                          0.657  Aland Islands
# 2 1900-01-03              -3.196                          0.467  Aland Islands
# 3 1900-01-04               0.781                          0.224  Aland Islands
# 4 1900-01-05               4.960                          0.503  Aland Islands

# %%
# Intermediary dataframe suitable for testing two regression models and further clean-up.

df_climate_raw['Year_int'] = pd.DatetimeIndex(df_climate_raw['dt']).year
df_climate_raw['Year_period'] = pd.to_datetime(df_climate_raw['dt']).dt.to_period('Y')

df_climate_grouped = df_climate_raw.drop(columns=['dt']).groupby(['Country', 'Year_period']).mean().reset_index()
df_climate_grouped['AverageTemperature'] = df_climate_grouped['AverageTemperature'].fillna(0)
df_climate_grouped.head()
# Out:
#        Country Year_period  AverageTemperature  AverageTemperatureUncertainty  \
# 0  Afghanistan        1900           13.749333                       0.748833
# 1  Afghanistan        1901           13.894000                       0.699333
# 2  Afghanistan        1902           14.505833                       0.726083
# 3  Afghanistan        1903           12.986417                       0.732333
# 4  Afghanistan        1904           13.805750                       0.713667
#
#    Year_int
# 0      1900
# 1      1901
# 2      1902
# 3      1903
# 4      1904

# %%
data = df_climate_grouped.loc[df_climate_grouped['Country'] == 'Afghanistan']
data.set_index((data['Year_period']), inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 114 entries, 1900 to 2013
# Freq: A-DEC
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        114 non-null    object
#  1   Year_period                    114 non-null    period[A-DEC]
#  2   AverageTemperature             114 non-null    float64
#  3   AverageTemperatureUncertainty  114 non-null    float64
#  4   Year_int                       114 non-null    int64
# dtypes: float64(2), int64(1), object(1), period[A-DEC](1)
# memory usage: 5.3+ KB

# %% [markdown]
# ***Test quality of predicted values created by autoregression model to further comparison with linear regression model.***

# %%
train, test = data.AverageTemperature[:-10], data.AverageTemperature[-10:]
model = AR(train)
model_fit = model.fit(maxlag=3)
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
b = pd.DataFrame({'observed':data.AverageTemperature[-10:], 'predicted':predictions})
b['var_sq'] = (b['observed'] - b['predicted'])**2
err_b = math.sqrt(b['var_sq'].sum())
err_b
# Out:
# C:\Users\gruzd\anaconda3\lib\site-packages\statsmodels\tsa\ar_model.py:691: FutureWarning:
# statsmodels.tsa.AR has been deprecated in favor of statsmodels.tsa.AutoReg and
# statsmodels.tsa.SARIMAX.
#
# AutoReg adds the ability to specify exogenous variables, include time trends,
# and add seasonal dummies. The AutoReg API differs from AR since the model is
# treated as immutable, and so the entire specification including the lag
# length must be specified when creating the model. This change is too
# substantial to incorporate into the existing AR api. The function
# ar_select_order performs lag length selection for AutoReg models.
#
# AutoReg only estimates parameters using conditional MLE (OLS). Use SARIMAX to
# estimate ARX and related models using full MLE via the Kalman Filter.
#
# To silence this warning and continue using AR until it is removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.ar_model.AR', FutureWarning)
#
#   warnings.warn(AR_DEPRECATION_WARN, FutureWarning)
# 3.3155264939607796

# %% [markdown]
# ***Test quality of predicted values created by linear model for further comparison with authoregression model.***

# %%
X = data['Year_int'].values.reshape(-1, 1)  # values converts it into a numpy array
Y = data['AverageTemperature'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
model = LinearRegression()
model.fit(X, Y)
Y_pred = model.predict(X)
Y_pred = [x[0] for x in Y_pred]
Y_pred

a = pd.DataFrame({'observed':data.AverageTemperature, 'predicted':Y_pred})
a['var_sq'] = (a['observed'] - a['predicted'])**2
err_a = math.sqrt(a['var_sq'][-10:].sum())
err_a
# Out:
# 2.1633887739079056

# %% [markdown]
# ***Linear regression has smaller error so we will use it to predict temperature for missing years.***

# %%
df_climate = pd.DataFrame({'Country':[], 'Year':[], 'AverageTemperature':[]})
for country in df_climate_grouped['Country'].unique():
    data = df_climate_grouped.loc[df_climate_grouped['Country'] == country]
    X = data['Year_int'].values.reshape(-1, 1)  # values converts it into a numpy array
    Y = data['AverageTemperature'].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
    model = LinearRegression()
    model.fit(X, Y)
    intercept = model.intercept_[0]
    slope = model.coef_[0][0]
    for year in range(2015, 2020):
        temp = slope*year + intercept
        df_climate = df_climate.append({'Country':country, 'Year':year, 'AverageTemperature':temp}, ignore_index=True)
df_climate['Year'] = df_climate['Year'].astype('int')
df_climate.head()
# Out:
#        Country  Year  AverageTemperature
# 0  Afghanistan  2015           15.084436
# 1  Afghanistan  2016           15.098997
# 2  Afghanistan  2017           15.113559
# 3  Afghanistan  2018           15.128120
# 4  Afghanistan  2019           15.142681

# %%
# Check spelling of countries. It should be unified accross all data sets as this field will be used for merging eventually.

df_climate['Country_Code'] = df_climate.apply(lambda row: country_code(row), axis=1)
df_climate.head()
df_climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1215 entries, 0 to 1214
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             1215 non-null   object
#  1   Year                1215 non-null   int32
#  2   AverageTemperature  1215 non-null   float64
#  3   Country_Code        970 non-null    object
# dtypes: float64(1), int32(1), object(2)
# memory usage: 33.3+ KB

# %%
# List of countries which spelling is different from international standards.

df_climate.loc[df_climate['Country_Code'].isnull()]['Country'].unique()
# Out:
# array(['Africa', 'Antigua And Barbuda', 'Asia', 'Baker Island',
#        'Bonaire, Saint Eustatius And Saba', 'Bosnia And Herzegovina',
#        'British Virgin Islands', 'Burma', 'Cape Verde',
#        'Congo (Democratic Republic Of The)', 'CuraÃ§ao', "CÃ´te D'Ivoire",
#        'Denmark (Europe)', 'Europe', 'Falkland Islands (Islas Malvinas)',
#        'Federated States Of Micronesia', 'France (Europe)',
#        'French Southern And Antarctic Lands', 'Gaza Strip',
#        'Guinea Bissau', 'Heard Island And Mcdonald Islands',
#        'Isle Of Man', 'Kingman Reef', 'Macau', 'Netherlands (Europe)',
#        'North America', 'North Korea', 'Oceania', 'Palestina',
#        'Palmyra Atoll', 'Reunion', 'Russia', 'Saint BarthÃ©lemy',
#        'Saint Kitts And Nevis', 'Saint Martin',
#        'Saint Pierre And Miquelon', 'Saint Vincent And The Grenadines',
#        'Sao Tome And Principe', 'Sint Maarten', 'South America',
#        'South Georgia And The South Sandwich Isla',
#        'Svalbard And Jan Mayen', 'Swaziland', 'Taiwan', 'Timor Leste',
#        'Trinidad And Tobago', 'Turks And Caicas Islands',
#        'United Kingdom (Europe)', 'Virgin Islands'], dtype=object)

# %% [markdown]
# **Delete from Climate:**
#
# 'Africa'\
# 'Asia'\
# 'Europe'\
# 'Oceania'\
# 'North America'\
# 'South America'
#
# **Rename in Climate:**
#
# 'Denmark (Europe)'\
# 'France (Europe)'\
# 'Macau'\
# 'Netherlands (Europe)'\
# 'Swaziland'\
# 'Taiwan'\
# 'North Korea'\
# 'Palestina'\
# 'Russia'\
# 'United Kingdom (Europe)'\
# 'Congo (Democratic Republic Of The)'\
# 'Antigua And Barbuda' ---> 'Antigua and Barbuda'\
# 'Bonaire, Saint Eustatius And Saba' ---> 'Bonaire, Sint Eustatius and Saba'\
# 'Bosnia And Herzegovina' ---> 'Bosnia and Herzegovina'\
# 'British Virgin Islands' ---> 'Virgin Islands (British)'\
# 'Burma' ---> 'Myanmar'\
# 'Cape Verde' ---> 'Cabo Verde'\
# "CÃ´te D'Ivoire" ---> "Côte d'Ivoire"\
# 'Falkland Islands (Islas Malvinas)' ---> 'Falkland Islands [Malvinas]'\
# 'Federated States Of Micronesia'---> 'Micronesia (Federated States of)'\
# 'Guinea Bissau' ---> 'Guinea-Bissau'\
# 'Isle Of Man' ---> 'Isle of Man'\
# 'Saint Kitts And Nevis' ---> 'Saint Kitts and Nevis'\
# 'Saint Pierre And Miquelon' ---> 'Saint Pierre and Miquelon'\
# 'Saint Vincent And The Grenadines' ---> 'Saint Vincent and the Grenadines'\
# 'Sao Tome And Principe' ---> 'Sao Tome and Principe'\
# 'South Georgia And The South Sandwich Isla' ---> 'South Georgia and the South Sandwich Islands'\
# 'Svalbard And Jan Mayen' ---> 'Svalbard and Jan Mayen'\
# 'Timor Leste' ---> 'Timor-Leste'\
# 'Trinidad And Tobago' ---> 'Trinidad and Tobago'\
# 'Turks And Caicas Islands' ---> 'Turks and Caicos Islands'\
# 'Virgin Islands' ----> 'Virgin Islands (U.S.)'
#
# **Put them on map:**
#
# 'CuraÃ§ao'\
# 'Sint Maarten'\
# 'Saint Martin'\
# 'Baker Island'\
# 'French Southern And Antarctic Lands'\
# 'Gaza Strip'\
# 'Heard Island And Mcdonald Islands'\
# 'Kingman Reef'\
# 'Palmyra Atoll'\
# 'Reunion'\
# 'Saint BarthÃ©lemy'

# %%
# Delete rows containing consolidated info per continent.
lst_delete = ['Africa', 'Asia', 'Europe', 'Oceania', 'North America', 'South America']
df_climate = df_climate[df_climate['Country'].isin(lst_delete) == False]

# Rename countries to align with ISO.
old_names = ['Denmark (Europe)', 'France (Europe)', 'Macau', 'Netherlands (Europe)', 'Swaziland', 'Taiwan', 'North Korea',
             'Palestina', 'Russia', 'United Kingdom (Europe)', 'Congo (Democratic Republic Of The)', 'Antigua And Barbuda',
             'Bonaire, Saint Eustatius And Saba', 'Bosnia And Herzegovina', 'British Virgin Islands', 'Burma', 'Cape Verde',
             "CÃ´te D'Ivoire", 'Falkland Islands (Islas Malvinas)', 'Guinea Bissau', 'Isle Of Man', 'Saint Kitts And Nevis',
             'Saint Pierre And Miquelon', 'Saint Vincent And The Grenadines', 'Sao Tome And Principe',
             'South Georgia And The South Sandwich Isla', 'Svalbard And Jan Mayen', 'Timor Leste', 'Trinidad And Tobago',
             'Turks And Caicas Islands', 'Virgin Islands']

new_names = ['Denmark', 'France', 'Macao', 'Netherlands', 'Swaziland (Eswatini)', 'Taiwan (Province of China)',
             "Korea (the Democratic People's Republic of)", 'Palestine', 'Russian Federation', 'United Kingdom',
             'Congo (the Democratic Republic of the)', 'Antigua and Barbuda', 'Bonaire, Sint Eustatius and Saba',
             'Bosnia and Herzegovina', 'Virgin Islands (British)', 'Myanmar', 'Cabo Verde', "Côte d'Ivoire",
             'Falkland Islands [Malvinas]', 'Guinea-Bissau', 'Isle of Man', 'Saint Kitts and Nevis', 'Saint Pierre and Miquelon',
             'Saint Vincent and the Grenadines', 'Sao Tome and Principe', 'South Georgia and the South Sandwich Islands',
             'Svalbard and Jan Mayen', 'Timor-Leste', 'Trinidad and Tobago', 'Turks and Caicos Islands', 'Virgin Islands (U.S.)']

df_climate['Country'].replace(old_names, new_names, inplace=True)

# %%
# Second check to see that everything is unified now.

df_climate['Country_Code'] = df_climate.apply(lambda row: country_code(row), axis=1)
df_climate.loc[df_climate['Country_Code'].isnull()]['Country'].unique()

# There are various territosies which are not relevant for analysis but would be nice to be shouwn on a map.
# Out:
# array(['Baker Island', 'CuraÃ§ao', 'Federated States Of Micronesia',
#        'French Southern And Antarctic Lands', 'Gaza Strip',
#        'Heard Island And Mcdonald Islands', 'Kingman Reef',
#        'Palmyra Atoll', 'Reunion', 'Saint BarthÃ©lemy', 'Saint Martin',
#        'Sint Maarten'], dtype=object)

# %%
df_climate['Year'].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019])

# %%
df_climate.groupby(df_climate['Country']).count()['Year'].sort_values(ascending=False)
# Out:
# Country
# France            10
# Denmark           10
# Netherlands       10
# United Kingdom    10
# French Guiana      5
#                   ..
# Nicaragua          5
# New Zealand        5
# New Caledonia      5
# Nepal              5
# Afghanistan        5
# Name: Year, Length: 233, dtype: int64

# %%
# Four countries contain two data sets - for continent and islands. As variance is not big we will take average.
df_climate.loc[df_climate['Country'].str.contains('Netherlands')]
# Out:
#          Country  Year  AverageTemperature Country_Code
# 760  Netherlands  2015           10.426569          NLD
# 761  Netherlands  2016           10.437039          NLD
# 762  Netherlands  2017           10.447509          NLD
# 763  Netherlands  2018           10.457979          NLD
# 764  Netherlands  2019           10.468450          NLD
# 765  Netherlands  2015           10.034423          NLD
# 766  Netherlands  2016           10.044901          NLD
# 767  Netherlands  2017           10.055378          NLD
# 768  Netherlands  2018           10.065856          NLD
# 769  Netherlands  2019           10.076334          NLD

# %%
# To keep country code in data frame.

df_climate = df_climate[['Country', 'Year', 'AverageTemperature']].pivot_table(index=['Country', 'Year']).reset_index()
df_climate.loc[df_climate['Country'] == 'Netherlands']
# Out:
#          Country  Year  AverageTemperature
# 735  Netherlands  2015           10.230496
# 736  Netherlands  2016           10.240970
# 737  Netherlands  2017           10.251444
# 738  Netherlands  2018           10.261918
# 739  Netherlands  2019           10.272392

# %%
# Adding country codes back for further use.

df_climate['Country_Code'] = df_climate.apply(lambda row: country_code(row), axis=1)

# %%
df_climate.to_sql('temperature_consol', engine, 'world_happiness', if_exists='replace')
df_climate.to_csv('.\\tableau_data\\temperature_consol.csv')

# %% [markdown]
# ***Consolidate all obtained and cleaned data into one dataframe for further analysis.***

# %%
df_suicide['Year'].unique()
# Out:
# array([2017, 2018, 2015, 2016], dtype=int64)

# %%
df_climate['Year'].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
df_climate_cut = df_climate[df_climate['Year'].isin([2015, 2016, 2017, 2018]) == True]
df_climate_cut['Year'].unique()
# Out:
# array([2015, 2016, 2017, 2018], dtype=int64)

# %%
df_happiness['Year'].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2019])

# %%
df_happiness_cut = df_happiness[df_happiness['Year'].isin([2015, 2016, 2017, 2018]) == True]
df_happiness_cut['Year'].unique()
# Out:
# array([2015, 2016, 2017, 2018])

# %%
df0 = pd.merge(df_happiness_cut, df_climate_cut, on = ['Country', 'Year'], how = 'outer')
df = pd.merge(df0, df_suicide, left_on = ['Country_Code_y', 'Year'], right_on = ['Country_Code', 'Year'], how = 'outer')
df.rename(columns={'Country_x':'Country',
                   'Country_y':'Country_c',
                   'Country_Code_x':'Country_Code_h',
                   'Country_Code_y':'Country_Code_c',
                   'Country_Code':'Country_Code_s'}, inplace=True)
# Spot check to verify data.
df.loc[df['Country'] == 'Netherlands']
df.loc[df['Country'] == 'Russian Federation']
df.loc[df['Country'] == 'China']
df.loc[df['Country'] == 'United States']
# df.info()
# Out:
#            Country  Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# 14   United States            15.0            7.119                 1.39451
# 182  United States            13.0            7.104                 1.50796
# 352  United States            14.0            6.993                 1.54626
# 523  United States            18.0            6.886                 1.39800
#
#      Social_support  Health_Life_Expectancy   Freedom  \
# 14          1.24711                0.861790  0.546040
# 182         1.04782                0.779000  0.481630
# 352         1.41992                0.774287  0.505741
# 523         1.47100                0.819000  0.547000
#
#      Trust_Government_Corruption  Generosity  Year Country_Code_h  \
# 14                      0.158900    0.401050  2015            USA
# 182                     0.148680    0.410770  2016            USA
# 352                     0.135639    0.392579  2017            USA
# 523                     0.133000    0.291000  2018            USA
#
#      AverageTemperature Country_Code_c      Country_c  Suicide_rate_per_100K  \
# 14             9.536333            USA  United States                   15.0
# 182            9.546196            USA  United States                   15.3
# 352            9.556059            USA  United States                   14.5
# 523            9.565921            USA            NaN                    NaN
#
#     Country_Code_s
# 14             USA
# 182            USA
# 352            USA
# 523            NaN

# %%
df.to_sql('total_consol_2015_2018', engine, 'world_happiness', if_exists='replace')
df.to_csv('.\\tableau_data\\total_consol_2015_2018.csv')

# %% [markdown]
# ## **Step 2.** Analysis of consolidated dataframe.

# %%
df = pd.read_sql_query('''SELECT * FROM world_happiness.total_consol_2015_2018''', engine)
df.drop(['index'], axis=1, inplace=True)
df.head()
# Out:
#        Country  Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# 0  Switzerland             1.0            7.587                 1.39651
# 1      Iceland             2.0            7.561                 1.30232
# 2      Denmark             3.0            7.527                 1.32548
# 3       Norway             4.0            7.522                 1.45900
# 4       Canada             5.0            7.427                 1.32629
#
#    Social_support  Health_Life_Expectancy  Freedom  \
# 0         1.34951                 0.94143  0.66557
# 1         1.40223                 0.94784  0.62877
# 2         1.36058                 0.87464  0.64938
# 3         1.33095                 0.88521  0.66973
# 4         1.32261                 0.90563  0.63297
#
#    Trust_Government_Corruption  Generosity  Year Country_Code_h  \
# 0                      0.41978     0.29678  2015            CHE
# 1                      0.14145     0.43630  2015            ISL
# 2                      0.48357     0.34139  2015            DNK
# 3                      0.36503     0.34699  2015            NOR
# 4                      0.32957     0.45811  2015            CAN
#
#    AverageTemperature Country_Code_c    Country_c  Suicide_rate_per_100K  \
# 0            7.975547            CHE  Switzerland                   17.1
# 1            2.184145            ISL      Iceland                   14.0
# 2           -4.132854            DNK      Denmark                   11.9
# 3            1.066703            NOR       Norway                   12.4
# 4           -3.837745            CAN       Canada                   12.5
#
#   Country_Code_s
# 0            CHE
# 1            ISL
# 2            DNK
# 3            NOR
# 4            CAN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1051 entries, 0 to 1050
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      949 non-null    object
#  1   Happiness_Rank               626 non-null    float64
#  2   Happiness_Score              626 non-null    float64
#  3   Economy_GDP_per_Capita       626 non-null    float64
#  4   Social_support               626 non-null    float64
#  5   Health_Life_Expectancy       626 non-null    float64
#  6   Freedom                      626 non-null    float64
#  7   Trust_Government_Corruption  626 non-null    float64
#  8   Generosity                   626 non-null    float64
#  9   Year                         1051 non-null   int64
#  10  Country_Code_h               612 non-null    object
#  11  AverageTemperature           932 non-null    float64
#  12  Country_Code_c               884 non-null    object
#  13  Country_c                    486 non-null    object
#  14  Suicide_rate_per_100K        486 non-null    float64
#  15  Country_Code_s               486 non-null    object
# dtypes: float64(10), int64(1), object(5)
# memory usage: 131.5+ KB

# %%
df_filled_only = df.loc[df['Suicide_rate_per_100K'].notnull()].loc[df['Happiness_Rank'].notnull()]
df_filled_only.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 327 entries, 0 to 583
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      327 non-null    object
#  1   Happiness_Rank               327 non-null    float64
#  2   Happiness_Score              327 non-null    float64
#  3   Economy_GDP_per_Capita       327 non-null    float64
#  4   Social_support               327 non-null    float64
#  5   Health_Life_Expectancy       327 non-null    float64
#  6   Freedom                      327 non-null    float64
#  7   Trust_Government_Corruption  327 non-null    float64
#  8   Generosity                   327 non-null    float64
#  9   Year                         327 non-null    int64
#  10  Country_Code_h               327 non-null    object
#  11  AverageTemperature           327 non-null    float64
#  12  Country_Code_c               327 non-null    object
#  13  Country_c                    327 non-null    object
#  14  Suicide_rate_per_100K        327 non-null    float64
#  15  Country_Code_s               327 non-null    object
# dtypes: float64(10), int64(1), object(5)
# memory usage: 43.4+ KB

# %%
df.describe()
# Out:
#        Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# count      626.000000       626.000000              626.000000
# mean        78.747604         5.372021                0.918764
# std         45.219609         1.131774                0.409808
# min          1.000000         2.693000                0.000000
# 25%         40.000000         4.497750                0.606755
# 50%         79.000000         5.307000                0.983704
# 75%        118.000000         6.187250                1.239502
# max        158.000000         7.632000                2.096000
#
#        Social_support  Health_Life_Expectancy     Freedom  \
# count      626.000000              626.000000  626.000000
# mean         1.045891                0.584299    0.415706
# std          0.328946                0.241948    0.154943
# min          0.000000                0.000000    0.000000
# 25%          0.847945                0.404143    0.310500
# 50%          1.081275                0.632553    0.434635
# 75%          1.283383                0.772957    0.538998
# max          1.644000                1.030000    0.724000
#
#        Trust_Government_Corruption  Generosity         Year  \
# count                   626.000000  626.000000  1051.000000
# mean                      0.128932    0.226981  2016.402474
# std                       0.108238    0.126854     1.113875
# min                       0.000000    0.000000  2015.000000
# 25%                       0.056141    0.137263  2015.000000
# 50%                       0.093574    0.208582  2016.000000
# 75%                       0.161340    0.290915  2017.000000
# max                       0.551910    0.838075  2018.000000
#
#        AverageTemperature  Suicide_rate_per_100K
# count          932.000000             486.000000
# mean            19.650902               9.563653
# std              8.952886               5.701603
# min            -17.541515               0.500000
# 25%             12.160691               5.300000
# 50%             23.691709               8.484520
# 75%             26.987270              12.800000
# max             29.559294              34.900000

# %%
df_filled_only.describe()
# Out:
#        Happiness_Rank  Happiness_Score  Economy_GDP_per_Capita  \
# count      327.000000       327.000000              327.000000
# mean        74.905199         5.485309                0.938215
# std         46.419865         1.167469                0.412240
# min          1.000000         2.839000                0.000000
# 25%         34.000000         4.557500                0.638715
# 50%         73.000000         5.488000                1.020540
# 75%        115.500000         6.433000                1.269970
# max        158.000000         7.587000                1.824270
#
#        Social_support  Health_Life_Expectancy     Freedom  \
# count      327.000000              327.000000  327.000000
# mean         0.942635                0.609284    0.408986
# std          0.317327                0.234136    0.151434
# min          0.000000                0.000000    0.000000
# 25%          0.758685                0.453300    0.308190
# 50%          0.978410                0.652130    0.416910
# 75%          1.156360                0.794335    0.533360
# max          1.644000                1.025250    0.677000
#
#        Trust_Government_Corruption  Generosity         Year  \
# count                   327.000000  327.000000   327.000000
# mean                      0.138866    0.237490  2015.633028
# std                       0.114680    0.131443     0.664534
# min                       0.000000    0.000000  2015.000000
# 25%                       0.059189    0.144850  2015.000000
# 50%                       0.105010    0.215420  2016.000000
# 75%                       0.178610    0.316211  2016.000000
# max                       0.551910    0.819710  2018.000000
#
#        AverageTemperature  Suicide_rate_per_100K
# count          327.000000             327.000000
# mean            17.816753               9.971254
# std              8.608876               5.985481
# min             -4.242882               1.900000
# 25%             10.328761               5.450000
# 50%             20.541631               8.800000
# 75%             25.632889              13.100000
# max             29.526499              34.900000

# %%
sns.pairplot(df)

# %%
fig, ax = plt.subplots(figsize=(10,8))
sns.heatmap(df.corr().select_dtypes(include=np.number), annot=True, linewidths=.5, ax=ax)

# %%
sns.pairplot(df[['Happiness_Rank', 'AverageTemperature', 'Suicide_rate_per_100K', 'Year']])

# %%
df[['Happiness_Rank', 'AverageTemperature', 'Suicide_rate_per_100K', 'Year']].corr()
# Out:
#                        Happiness_Rank  AverageTemperature  \
# Happiness_Rank               1.000000            0.397666
# AverageTemperature           0.397666            1.000000
# Suicide_rate_per_100K       -0.290246           -0.514832
# Year                        -0.009822            0.001301
#
#                        Suicide_rate_per_100K      Year
# Happiness_Rank                     -0.290246 -0.009822
# AverageTemperature                 -0.514832  0.001301
# Suicide_rate_per_100K               1.000000  0.067411
# Year                                0.067411  1.000000

# %%
for column in df.select_dtypes(include=np.number):
    print(column)
    plt.boxplot(df[column].dropna())
    plt.show()
# Out:
# Happiness_Rank
# Happiness_Score
# Economy_GDP_per_Capita
# Social_support
# Health_Life_Expectancy
# Freedom
# Trust_Government_Corruption
# Generosity
# Year
# AverageTemperature
# Suicide_rate_per_100K

# %%
df.sort_values(by='Suicide_rate_per_100K', ascending=False)
# Out:
#                    Country  Happiness_Rank  Happiness_Score  \
# 55               Lithuania            56.0            5.833
# 63      Russian Federation            64.0            5.716
# 229              Lithuania            60.0            5.813
# 225     Russian Federation            56.0            5.856
# 802                 Guyana             NaN              NaN
# ..                     ...             ...              ...
# 944  Virgin Islands (U.S.)             NaN              NaN
# 945         Western Sahara             NaN              NaN
# 946         Western Sahara             NaN              NaN
# 947         Western Sahara             NaN              NaN
# 948         Western Sahara             NaN              NaN
#
#      Economy_GDP_per_Capita  Social_support  Health_Life_Expectancy  Freedom  \
# 55                  1.14723         1.25745                 0.73128  0.21342
# 63                  1.13764         1.23617                 0.66926  0.36679
# 229                 1.26920         1.06411                 0.64674  0.18929
# 225                 1.23228         1.05261                 0.58991  0.32682
# 802                     NaN             NaN                     NaN      NaN
# ..                      ...             ...                     ...      ...
# 944                     NaN             NaN                     NaN      NaN
# 945                     NaN             NaN                     NaN      NaN
# 946                     NaN             NaN                     NaN      NaN
# 947                     NaN             NaN                     NaN      NaN
# 948                     NaN             NaN                     NaN      NaN
#
#      Trust_Government_Corruption  Generosity  Year Country_Code_h  \
# 55                       0.01031     0.02641  2015            LTU
# 63                       0.03005     0.00199  2015            RUS
# 229                      0.01820     0.02025  2016            LTU
# 225                      0.03586     0.02736  2016            RUS
# 802                          NaN         NaN  2016           None
# ..                           ...         ...   ...            ...
# 944                          NaN         NaN  2018           None
# 945                          NaN         NaN  2015           None
# 946                          NaN         NaN  2016           None
# 947                          NaN         NaN  2017           None
# 948                          NaN         NaN  2018           None
#
#      AverageTemperature Country_Code_c           Country_c  \
# 55             6.990102            LTU           Lithuania
# 63            -4.242882            RUS  Russian Federation
# 229            7.002615            LTU           Lithuania
# 225           -4.227219            RUS  Russian Federation
# 802           26.780516            GUY              Guyana
# ..                  ...            ...                 ...
# 944           27.205161            VIR                None
# 945           23.255169            ESH                None
# 946           23.266587            ESH                None
# 947           23.278005            ESH                None
# 948           23.289423            ESH                None
#
#      Suicide_rate_per_100K Country_Code_s
# 55                    34.9            LTU
# 63                    32.1            RUS
# 229                   31.9            LTU
# 225                   31.0            RUS
# 802                   29.2            GUY
# ..                     ...            ...
# 944                    NaN           None
# 945                    NaN           None
# 946                    NaN           None
# 947                    NaN           None
# 948                    NaN           None
#
# [1051 rows x 16 columns]

# %%
df['Suicide_provided'] = np.where(df['Suicide_rate_per_100K'].isnull(), 0, 1)
df['AverageTemperature'].corr(df['Suicide_provided'])
# Out:
# -0.06360133841442389

# %% [markdown]
# ## **Step 3.** Hypothesis testing.

# %% [markdown]
# **Test 1.** ANOVA: null hypothesis - happiness ratio is the same for all countries.

# %%
df_temp = df[['Country', 'Happiness_Score', 'Year']].dropna()
df_temp
# Out:
#                       Country  Happiness_Score  Year
# 0                 Switzerland            7.587  2015
# 1                     Iceland            7.561  2015
# 2                     Denmark            7.527  2015
# 3                      Norway            7.522  2015
# 4                      Canada            7.427  2015
# ..                        ...              ...   ...
# 669                    Rwanda            3.408  2018
# 670                     Yemen            3.355  2018
# 671                  Tanzania            3.303  2018
# 672  Central African Republic            3.083  2018
# 673                   Burundi            2.905  2018
#
# [626 rows x 3 columns]

# %%
df_temp = df[['Country', 'Happiness_Score', 'Year']].dropna()

anova_list = []
for country in df_temp['Country'].unique():
    anova_list.append(df_temp.loc[df_temp['Country'] == country]['Happiness_Score'])
anova_list
# Out:
# [0      7.587
#  171    7.509
#  342    7.494
#  510    7.487
#  Name: Happiness_Score, dtype: float64,
#  1      7.561
#  172    7.501
#  341    7.504
#  509    7.495
#  Name: Happiness_Score, dtype: float64,
#  2      7.527
#  170    7.526
#  340    7.522
#  508    7.555
#  Name: Happiness_Score, dtype: float64,
#  3      7.522
#  173    7.498
#  339    7.537
#  507    7.594
#  Name: Happiness_Score, dtype: float64,
#  4      7.427
#  175    7.404
#  345    7.316
#  512    7.328
#  Name: Happiness_Score, dtype: float64,
#  5      7.406
#  174    7.413
#  343    7.469
#  506    7.632
#  Name: Happiness_Score, dtype: float64,
#  6      7.378
#  176    7.339
#  344    7.377
#  511    7.441
#  Name: Happiness_Score, dtype: float64,
#  7      7.364
#  179    7.291
#  347    7.284
#  514    7.314
#  Name: Happiness_Score, dtype: float64,
#  8      7.286
#  177    7.334
#  346    7.314
#  513    7.324
#  Name: Happiness_Score, dtype: float64,
#  9      7.284
#  178    7.313
#  348    7.284
#  515    7.272
#  Name: Happiness_Score, dtype: float64,
#  10     7.278
#  180    7.267
#  349    7.213
#  524    6.814
#  Name: Happiness_Score, dtype: float64,
#  11     7.226
#  183    7.087
#  350    7.079
#  518    7.072
#  Name: Happiness_Score, dtype: float64,
#  12     7.200
#  181    7.119
#  351    7.006
#  517    7.139
#  Name: Happiness_Score, dtype: float64,
#  13     7.187
#  190    6.778
#  363    6.578
#  529    6.488
#  Name: Happiness_Score, dtype: float64,
#  14     7.119
#  182    7.104
#  352    6.993
#  523    6.886
#  Name: Happiness_Score, dtype: float64,
#  15     6.983
#  186    6.952
#  360    6.635
#  533    6.419
#  Name: Happiness_Score, dtype: float64,
#  16     6.946
#  189    6.871
#  356    6.863
#  522    6.910
#  Name: Happiness_Score, dtype: float64,
#  17     6.940
#  188    6.907
#  353    6.977
#  519    6.977
#  Name: Happiness_Score, dtype: float64,
#  18     6.937
#  187    6.929
#  355    6.891
#  521    6.927
#  Name: Happiness_Score, dtype: float64,
#  19     6.901
#  197    6.573
#  359    6.648
#  525    6.774
#  Name: Happiness_Score, dtype: float64,
#  20     6.867
#  192    6.725
#  357    6.714
#  516    7.190
#  Name: Happiness_Score, dtype: float64,
#  21    6.853
#  Name: Happiness_Score, dtype: float64,
#  22     6.810
#  213    6.084
#  434    5.250
#  621    4.806
#  Name: Happiness_Score, dtype: float64,
#  23     6.798
#  191    6.739
#  364    6.572
#  539    6.343
#  Name: Happiness_Score, dtype: float64,
#  24     6.786
#  194    6.701
#  368    6.452
#  532    6.430
#  Name: Happiness_Score, dtype: float64,
#  25     6.750
#  185    6.994
#  354    6.951
#  520    6.965
#  Name: Happiness_Score, dtype: float64,
#  26     6.670
#  193    6.705
#  358    6.652
#  530    6.476
#  Name: Happiness_Score, dtype: float64,
#  27     6.611
#  205    6.375
#  373    6.375
#  537    6.374
#  Name: Happiness_Score, dtype: float64,
#  28     6.575
#  201    6.478
#  369    6.442
#  528    6.489
#  Name: Happiness_Score, dtype: float64,
#  29     6.574
#  195    6.650
#  362    6.599
#  534    6.388
#  Name: Happiness_Score, dtype: float64,
#  30     6.505
#  196    6.596
#  361    6.609
#  526    6.711
#  Name: Happiness_Score, dtype: float64,
#  31     6.485
#  198    6.545
#  366    6.454
#  536    6.379
#  Name: Happiness_Score, dtype: float64,
#  32     6.477
#  200    6.481
#  374    6.357
#  542    6.260
#  Name: Happiness_Score, dtype: float64,
#  33     6.455
#  202    6.474
#  370    6.424
#  551    6.072
#  Name: Happiness_Score, dtype: float64,
#  34     6.411
#  203    6.379
#  375    6.344
#  538    6.371
#  Name: Happiness_Score, dtype: float64,
#  35     6.329
#  206    6.361
#  372    6.403
#  541    6.310
#  Name: Happiness_Score, dtype: float64,
#  36     6.302
#  199    6.488
#  365    6.527
#  527    6.627
#  Name: Happiness_Score, dtype: float64,
#  37     6.298
#  204    6.379
#  371    6.422
#  531    6.441
#  Name: Happiness_Score, dtype: float64,
#  38     6.295
#  210    6.239
#  377    6.105
#  550    6.083
#  Name: Happiness_Score, dtype: float64,
#  39     6.269
#  209    6.269
#  Name: Happiness_Score, dtype: float64,
#  40     6.168
#  212    6.168
#  376    6.168
#  543    6.192
#  Name: Happiness_Score, dtype: float64,
#  41     6.130
#  215    6.068
#  383    6.003
#  545    6.167
#  Name: Happiness_Score, dtype: float64,
#  42     6.123
#  208    6.324
#  367    6.454
#  535    6.382
#  Name: Happiness_Score, dtype: float64,
#  43     6.003
#  218    5.987
#  385    5.971
#  549    6.096
#  Name: Happiness_Score, dtype: float64,
#  44     5.995
#  214    6.078
#  378    6.098
#  544    6.173
#  Name: Happiness_Score, dtype: float64,
#  45     5.987
#  222    5.921
#  389    5.920
#  559    5.915
#  Name: Happiness_Score, dtype: float64,
#  46     5.984
#  227    5.835
#  393    5.838
#  562    5.875
#  Name: Happiness_Score, dtype: float64,
#  47     5.975
#  220    5.976
#  382    6.008
#  553    5.973
#  Name: Happiness_Score, dtype: float64,
#  48     5.960
#  211    6.218
#  379    6.087
#  548    6.105
#  Name: Happiness_Score, dtype: float64,
#  49     5.948
#  219    5.977
#  386    5.964
#  552    6.000
#  Name: Happiness_Score, dtype: float64,
#  50     5.890
#  228    5.822
#  396    5.823
#  582    5.752
#  Name: Happiness_Score, dtype: float64,
#  51     5.889
#  224    5.897
#  394    5.838
#  586    5.640
#  Name: Happiness_Score, dtype: float64,
#  52     5.878
#  255    5.538
#  423    5.493
#  584    5.681
#  Name: Happiness_Score, dtype: float64,
#  53     5.855
#  223    5.919
#  398    5.819
#  580    5.790
#  Name: Happiness_Score, dtype: float64,
#  54     5.848
#  248    5.768
#  415    5.758
#  556    5.948
#  Name: Happiness_Score, dtype: float64,
#  55     5.833
#  229    5.813
#  390    5.902
#  555    5.952
#  Name: Happiness_Score, dtype: float64,
#  56     5.828
#  217    5.992
#  381    6.071
#  546    6.141
#  Name: Happiness_Score, dtype: float64,
#  57     5.824
#  249    5.743
#  416    5.715
#  585    5.663
#  Name: Happiness_Score, dtype: float64,
#  58     5.813
#  230    5.802
#  420    5.569
#  592    5.483
#  Name: Happiness_Score, dtype: float64,
#  59     5.791
#  226    5.835
#  384    5.973
#  547    6.123
#  Name: Happiness_Score, dtype: float64,
#  60     5.770
#  216    6.005
#  380    6.084
#  540    6.322
#  Name: Happiness_Score, dtype: float64,
#  61     5.759
#  259    5.488
#  430    5.293
#  601    5.321
#  Name: Happiness_Score, dtype: float64,
#  62     5.754
#  252    5.615
#  421    5.525
#  589    5.566
#  Name: Happiness_Score, dtype: float64,
#  63     5.716
#  225    5.856
#  387    5.963
#  579    5.810
#  Name: Happiness_Score, dtype: float64,
#  64     5.709
#  258    5.510
#  429    5.311
#  561    5.890
#  Name: Happiness_Score, dtype: float64,
#  65     5.695
#  231    5.771
#  399    5.810
#  563    5.835
#  Name: Happiness_Score, dtype: float64,
#  66     5.589
#  232    5.401
#  400    5.279
#  564    5.662
#  Name: Happiness_Score, dtype: float64,
#  67     5.057
#  233    5.057
#  Name: Happiness_Score, dtype: float64,
#  68     3.655
#  234    3.916
#  401    4.180
#  565    4.671
#  Name: Happiness_Score, dtype: float64,
#  81     5.689
#  254    5.546
#  418    5.621
#  581    5.762
#  Name: Happiness_Score, dtype: float64,
#  82     5.605
#  207    6.355
#  391    5.872
#  603    5.295
#  Name: Happiness_Score, dtype: float64,
#  83     5.548
#  250    5.658
#  397    5.822
#  587    5.636
#  Name: Happiness_Score, dtype: float64,
#  84     5.477
#  251    5.648
#  417    5.629
#  560    5.891
#  Name: Happiness_Score, dtype: float64,
#  85     5.474
#  260    5.458
#  424    5.472
#  595    5.430
#  Name: Happiness_Score, dtype: float64,
#  86     5.429
#  257    5.517
#  419    5.611
#  583    5.739
#  Name: Happiness_Score, dtype: float64,
#  87     5.399
#  263    5.314
#  433    5.262
#  615    5.093
#  Name: Happiness_Score, dtype: float64,
#  88     5.360
#  280    5.061
#  446    5.074
#  614    5.103
#  Name: Happiness_Score, dtype: float64,
#  89     5.332
#  262    5.389
#  422    5.500
#  593    5.483
#  Name: Happiness_Score, dtype: float64,
#  90     5.286
#  269    5.185
#  450    5.004
#  611    5.131
#  Name: Happiness_Score, dtype: float64,
#  91     5.268
#  286    4.875
#  447    5.074
#  610    5.155
#  Name: Happiness_Score, dtype: float64,
#  92     5.253
#  268    5.196
#  449    5.011
#  616    5.082
#  Name: Happiness_Score, dtype: float64,
#  93     5.212
#  265    5.291
#  437    5.234
#  606    5.201
#  Name: Happiness_Score, dtype: float64,
#  94     5.194
#  276    5.132
#  432    5.269
#  594    5.472
#  Name: Happiness_Score, dtype: float64,
#  95     5.192
#  264    5.303
#  427    5.336
#  609    5.161
#  Name: Happiness_Score, dtype: float64,
#  96     5.192
#  272    5.161
#  435    5.237
#  600    5.347
#  Name: Happiness_Score, dtype: float64,
#  97     5.140
#  267    5.245
#  431    5.273
#  605    5.246
#  Name: Happiness_Score, dtype: float64,
#  98     5.129
#  289    4.795
#  468    4.514
#  643    4.377
#  Name: Happiness_Score, dtype: float64,
#  99     5.124
#  256    5.528
#  395    5.825
#  557    5.945
#  Name: Happiness_Score, dtype: float64,
#  100    5.123
#  270    5.177
#  426    5.395
#  597    5.398
#  Name: Happiness_Score, dtype: float64,
#  101    5.102
#  278    5.123
#  441    5.195
#  596    5.410
#  Name: Happiness_Score, dtype: float64,
#  102    5.098
#  253    5.560
#  392    5.850
#  558    5.933
#  Name: Happiness_Score, dtype: float64,
#  103    5.073
#  266    5.279
#  425    5.430
#  590    5.524
#  Name: Happiness_Score, dtype: float64,
#  104    5.013
#  274    5.151
#  436    5.235
#  604    5.254
#  Name: Happiness_Score, dtype: float64,
#  105    5.007
#  279    5.121
#  444    5.175
#  608    5.185
#  Name: Happiness_Score, dtype: float64,
#  106    4.971
#  465    4.550
#  641    4.417
#  Name: Happiness_Score, dtype: float64,
#  107    4.959
#  292    4.655
#  461    4.644
#  630    4.586
#  Name: Happiness_Score, dtype: float64,
#  108    4.949
#  271    5.163
#  442    5.182
#  612    5.129
#  Name: Happiness_Score, dtype: float64,
#  109    4.898
#  490    3.808
#  659    3.808
#  Name: Happiness_Score, dtype: float64,
#  110    4.885
#  273    5.155
#  438    5.230
#  602    5.302
#  Name: Happiness_Score, dtype: float64,
#  111    4.876
#  285    4.876
#  628    4.623
#  Name: Happiness_Score, dtype: float64,
#  112    4.874
#  284    4.907
#  452    4.955
#  613    5.125
#  Name: Happiness_Score, dtype: float64,
#  113    4.867
#  Name: Happiness_Score, dtype: float64,
#  114    4.857
#  282    5.033
#  439    5.227
#  598    5.358
#  Name: Happiness_Score, dtype: float64,
#  115    4.839
#  277    5.129
#  440    5.225
#  599    5.358
#  Name: Happiness_Score, dtype: float64,
#  116    4.800
#  275    5.145
#  428    5.324
#  588    5.620
#  Name: Happiness_Score, dtype: float64,
#  117    4.788
#  287    4.871
#  443    5.181
#  591    5.504
#  Name: Happiness_Score, dtype: float64,
#  118    4.786
#  283    4.996
#  448    5.041
#  607    5.199
#  Name: Happiness_Score, dtype: float64,
#  119    4.739
#  281    5.045
#  454    4.805
#  629    4.592
#  Name: Happiness_Score, dtype: float64,
#  120    4.715
#  291    4.754
#  455    4.775
#  623    4.743
#  Name: Happiness_Score, dtype: float64,
#  121    4.694
#  293    4.643
#  462    4.608
#  633    4.500
#  Name: Happiness_Score, dtype: float64,
#  122    4.686
#  288    4.813
#  460    4.692
#  625    4.707
#  Name: Happiness_Score, dtype: float64,
#  123    4.681
#  306    4.324
#  483    4.096
#  656    4.103
#  Name: Happiness_Score, dtype: float64,
#  124    4.677
#  295    4.575
#  469    4.497
#  635    4.456
#  Name: Happiness_Score, dtype: float64,
#  125    4.642
#  299    4.459
#  453    4.829
#  624    4.724
#  Name: Happiness_Score, dtype: float64,
#  126    4.633
#  307    4.276
#  482    4.120
#  626    4.657
#  Name: Happiness_Score, dtype: float64,
#  127    4.610
#  314    4.193
#  489    3.875
#  662    3.692
#  Name: Happiness_Score, dtype: float64,
#  128    4.571
#  331    3.622
#  498    3.533
#  667    3.495
#  Name: Happiness_Score, dtype: float64,
#  129    4.565
#  301    4.404
#  474    4.315
#  651    4.190
#  Name: Happiness_Score, dtype: float64,
#  130    4.550
#  316    4.139
#  481    4.139
#  655    4.139
#  Name: Happiness_Score, dtype: float64,
#  131    4.518
#  319    4.028
#  496    3.603
#  666    3.582
#  Name: Happiness_Score, dtype: float64,
#  132    4.517
#  308    4.272
#  478    4.280
#  650    4.245
#  Name: Happiness_Score, dtype: float64,
#  133    4.514
#  290    4.793
#  451    4.962
#  620    4.880
#  Name: Happiness_Score, dtype: float64,
#  134    4.512
#  298    4.508
#  471    4.460
#  645    4.350
#  Name: Happiness_Score, dtype: float64,
#  135    4.507
#  294    4.635
#  458    4.709
#  631    4.571
#  Name: Happiness_Score, dtype: float64,
#  136    4.436
#  313    4.201
#  475    4.292
#  644    4.356
#  Name: Happiness_Score, dtype: float64,
#  137    4.419
#  305    4.356
#  464    4.553
#  642    4.410
#  Name: Happiness_Score, dtype: float64,
#  138    4.369
#  Name: Happiness_Score, dtype: float64,
#  139    4.350
#  304    4.360
#  473    4.376
#  647    4.321
#  Name: Happiness_Score, dtype: float64,
#  140    4.332
#  320    3.974
#  493    3.766
#  664    3.590
#  Name: Happiness_Score, dtype: float64,
#  141    4.307
#  302    4.395
#  466    4.545
#  648    4.308
#  Name: Happiness_Score, dtype: float64,
#  142    4.297
#  309    4.252
#  477    4.286
#  646    4.340
#  Name: Happiness_Score, dtype: float64,
#  143    4.292
#  315    4.156
#  487    3.970
#  665    3.587
#  Name: Happiness_Score, dtype: float64,
#  144    4.271
#  300    4.415
#  472    4.440
#  634    4.471
#  Name: Happiness_Score, dtype: float64,
#  145    4.252
#  297    4.513
#  459    4.695
#  618    4.975
#  Name: Happiness_Score, dtype: float64,
#  146    4.218
#  312    4.217
#  457    4.714
#  619    4.933
#  Name: Happiness_Score, dtype: float64,
#  147    4.194
#  303    4.362
#  456    4.735
#  640    4.419
#  Name: Happiness_Score, dtype: float64,
#  148    4.077
#  328    3.724
#  497    3.593
#  670    3.355
#  Name: Happiness_Score, dtype: float64,
#  149    4.033
#  323    3.866
#  491    3.795
#  660    3.795
#  Name: Happiness_Score, dtype: float64,
#  150    3.995
#  318    4.073
#  479    4.190
#  636    4.447
#  Name: Happiness_Score, dtype: float64,
#  151    3.989
#  310    4.236
#  476    4.291
#  632    4.559
#  Name: Happiness_Score, dtype: float64,
#  152    3.956
#  321    3.956
#  Name: Happiness_Score, dtype: float64,
#  153    3.931
#  327    3.739
#  484    4.081
#  653    4.161
#  Name: Happiness_Score, dtype: float64,
#  154    3.904
#  311    4.219
#  467    4.535
#  627    4.631
#  Name: Happiness_Score, dtype: float64,
#  155    3.896
#  317    4.121
#  470    4.465
#  622    4.758
#  Name: Happiness_Score, dtype: float64,
#  156    3.845
#  324    3.856
#  486    4.028
#  652    4.166
#  Name: Happiness_Score, dtype: float64,
#  157    3.819
#  322    3.907
#  480    4.168
#  638    4.433
#  Name: Happiness_Score, dtype: float64,
#  158    3.781
#  330    3.666
#  503    3.349
#  671    3.303
#  Name: Happiness_Score, dtype: float64,
#  159    3.681
#  329    3.695
#  495    3.644
#  661    3.774
#  Name: Happiness_Score, dtype: float64,
#  160    3.678
#  505    2.693
#  672    3.083
#  Name: Happiness_Score, dtype: float64,
#  161    3.667
#  325    3.763
#  488    3.936
#  649    4.301
#  Name: Happiness_Score, dtype: float64,
#  162    3.656
#  332    3.607
#  499    3.507
#  658    3.964
#  Name: Happiness_Score, dtype: float64,
#  163    3.587
#  326    3.739
#  485    4.032
#  639    4.424
#  Name: Happiness_Score, dtype: float64,
#  164    3.575
#  335    3.360
#  492    3.794
#  663    3.632
#  Name: Happiness_Score, dtype: float64,
#  165    3.465
#  333    3.515
#  501    3.471
#  669    3.408
#  Name: Happiness_Score, dtype: float64,
#  166    3.340
#  334    3.484
#  494    3.657
#  654    4.141
#  Name: Happiness_Score, dtype: float64,
#  167    3.006
#  337    3.069
#  502    3.462
#  668    3.462
#  Name: Happiness_Score, dtype: float64,
#  168    2.905
#  338    2.905
#  504    2.905
#  673    2.905
#  Name: Happiness_Score, dtype: float64,
#  169    2.839
#  336    3.303
#  500    3.495
#  657    3.999
#  Name: Happiness_Score, dtype: float64,
#  184    7.039
#  Name: Happiness_Score, dtype: float64,
#  221    5.956
#  388    5.956
#  554    5.956
#  Name: Happiness_Score, dtype: float64,
#  235    3.832
#  402    3.591
#  566    3.254
#  Name: Happiness_Score, dtype: float64,
#  261    5.440
#  445    5.151
#  617    4.982
#  Name: Happiness_Score, dtype: float64,
#  296    4.574
#  463    4.574
#  637    4.441
#  Name: Happiness_Score, dtype: float64]

# %%
stats.f_oneway(*anova_list)
# Out:
# F_onewayResult(statistic=111.07520614716898, pvalue=2.3477739971704874e-296)

# %% [markdown]
# P values is almost zero, so we should reject our null hypothesis. Also values of statistics says that there is a very big gap between happiness ratio across the world.

# %% [markdown]
# **Test 2.** ANOVA: null hypothesis - happiness ratio is not changing within time.

# %%
anova_list2 = []
for year in df_temp['Year'].unique():
    anova_list2.append(df_temp.loc[df_temp['Year'] == year]['Happiness_Score'])
anova_list2
# Out:
# [0      7.587
#  1      7.561
#  2      7.527
#  3      7.522
#  4      7.427
#         ...
#  165    3.465
#  166    3.340
#  167    3.006
#  168    2.905
#  169    2.839
#  Name: Happiness_Score, Length: 158, dtype: float64,
#  170    7.526
#  171    7.509
#  172    7.501
#  173    7.498
#  174    7.413
#         ...
#  334    3.484
#  335    3.360
#  336    3.303
#  337    3.069
#  338    2.905
#  Name: Happiness_Score, Length: 157, dtype: float64,
#  339    7.537
#  340    7.522
#  341    7.504
#  342    7.494
#  343    7.469
#         ...
#  501    3.471
#  502    3.462
#  503    3.349
#  504    2.905
#  505    2.693
#  Name: Happiness_Score, Length: 155, dtype: float64,
#  506    7.632
#  507    7.594
#  508    7.555
#  509    7.495
#  510    7.487
#         ...
#  669    3.408
#  670    3.355
#  671    3.303
#  672    3.083
#  673    2.905
#  Name: Happiness_Score, Length: 156, dtype: float64]

# %%
stats.f_oneway(*anova_list2)
# Out:
# F_onewayResult(statistic=0.01838764549633986, pvalue=0.9966068512377847)

# %% [markdown]
# P value is almost one which means we can't reject our null hypothesis. It means that probably there is no difference in happiness ratio from year to year. But we should keep in mind that we have only 4 years available for analysis and trends such as the one we testing are usually need more years to develop.

# %% [markdown]
# **Test 3.** Assuming that available information of suicide numbers per country are representative, let's calculate confidence intervals for whole world.

# %%
st_d = np.std(df['Suicide_rate_per_100K'].dropna())
m = df['Suicide_rate_per_100K'].dropna().mean()
conf_level = 0.95
n = len(df['Suicide_rate_per_100K'].dropna())
conf_int = stats.norm.interval(conf_level, m, st_d/np.sqrt(n))
conf_int
# Out:
# (9.05726955784428, 10.070036903098094)

# %% [markdown]
# There is a 95% chance that mean of full population lies between 9 and 10 suicides per 100K.

# %% [markdown]
# **Test 4.** 2-sided one sample test: Hypothesis - the country with the lowest temperature has the highest suicide rating. Then null hypothesis is that such country has the same as an average suicide rating.

# %%
df_temp = df[['Country', 'AverageTemperature', 'Suicide_rate_per_100K']].groupby('Country').mean().reset_index().dropna()
df_temp.nsmallest(10, 'AverageTemperature')
# Out:
#                 Country  AverageTemperature  Suicide_rate_per_100K
# 175  Russian Federation           -4.219388              31.550000
# 55              Denmark           -4.117140              12.350000
# 37               Canada           -3.814692              12.000000
# 141            Mongolia            0.603592              13.050000
# 158              Norway            1.081957              12.300000
# 96              Iceland            2.194519              11.850000
# 70              Finland            2.344663              14.966667
# 208              Sweden            3.389183              13.966667
# 117          Kyrgyzstan            4.467679               8.200000
# 212          Tajikistan            5.186796               2.500000

# %%
stat, pval = stats.ttest_1samp(df_temp['AverageTemperature'].to_numpy(), 19.74)
print(stat, pval)
# Out:
# -0.23908583790364762 0.8113156328694985

# %% [markdown]
# P value is almost zero, it means that our null hypotesis should be rejected. Also based on sign on statistics value we can say that real mean of population is lower than mean of Russian Federation. We still can't confirm our alternative hypothesis as we don't know if Russian Feredation has the highest suicide ratio but we know that its higher than average.
